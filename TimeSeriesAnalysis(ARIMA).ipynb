# %% [markdown]
# <a href="https://colab.research.google.com/github/yesaswiniswarna/FML/blob/main/TimeSeriesAnalysis(ARIMA).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from datetime import datetime
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 10,6

# %%
data = pd.read_csv("archive (2).zip")

# %%
data.head(3)
# Out:
#    region  tenure  age  marital  address  income  ed  employ  retire  gender  \
# 0       2      13   44        1        9    64.0   4       5     0.0       0
# 1       3      11   33        1        7   136.0   5       5     0.0       0
# 2       3      68   52        1       24   116.0   1      29     0.0       1
#
#    reside  custcat
# 0       2        1
# 1       6        4
# 2       2        3

# %%
data.tail(5)
# Out:
#      region  tenure  age  marital  address  income  ed  employ  retire  \
# 995       3      10   39        0        0    27.0   3       0     0.0
# 996       1       7   34        0        2    22.0   5       5     0.0
# 997       3      67   59        0       40   944.0   5      33     0.0
# 998       3      70   49        0       18    87.0   2      22     0.0
# 999       3      50   36        1        7    39.0   3       3     0.0
#
#      gender  reside  custcat
# 995       1       3        1
# 996       1       1        1
# 997       1       1        4
# 998       1       1        3
# 999       1       3        2

# %%
data.shape
# Out:
# (1000, 12)

# %%
data['region']=(data['region'])
indexedData=data.set_index(['region'])

# %%
indexedData.head(3)
# Out:
#                                tenure  age  marital  address  income  ed  \
# region
# 1970-01-01 00:00:00.000000002      13   44        1        9    64.0   4
# 1970-01-01 00:00:00.000000003      11   33        1        7   136.0   5
# 1970-01-01 00:00:00.000000003      68   52        1       24   116.0   1
#
#                                employ  retire  gender  reside  custcat
# region
# 1970-01-01 00:00:00.000000002       5     0.0       0       2        1
# 1970-01-01 00:00:00.000000003       5     0.0       0       6        4
# 1970-01-01 00:00:00.000000003      29     0.0       1       2        3
